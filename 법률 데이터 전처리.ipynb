# %%
import os
import json
import pandas as pd
from charset_normalizer import detect

# 경로 리스트
paths = [
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_08.특허.저작권",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_05.행정",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_02.가사",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_10.개인정보.ICT",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_06.기업",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_07.근로자",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_09.금융조세",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_03.형사A(생활형)",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_04.형사B(일반형)",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_01.민사"
]

# 추출할 컬럼 리스트
required_columns = [
    'info', 'jdgmn', 'jdgmnInfo', 'Summary', 'keyword_tagg', 'Reference_info', 'Class_info'
]

# 결과를 저장할 리스트
data = []

# 파일 탐색 및 데이터 추출
for path in paths:
    for file_name in os.listdir(path):
        if file_name.endswith('.json'):
            file_path = os.path.join(path, file_name)
            try:
                # 파일 인코딩 감지
                with open(file_path, 'rb') as f:
                    raw_data = f.read()
                    detected = detect(raw_data)
                    encoding = detected['encoding']

                # JSON 데이터 읽기
                with open(file_path, 'r', encoding=encoding) as file:
                    content = json.load(file)
                    # 컬럼 존재 여부 확인 및 추출
                    extracted_data = {col: content.get(col, None) for col in required_columns}
                    data.append(extracted_data)
            except Exception as e:
                print(f"오류 발생: {file_path}. {e}")

# DataFrame으로 변환 및 저장
df = pd.DataFrame(data)

# 빈 데이터프레임 확인
if df.empty:
    print("추출된 데이터가 없습니다. 파일 구조를 확인하세요.")
else:
    output_path = r"C:\Users\wjdtn\Downloads\law_data_extracted.csv"
    df.to_csv(output_path, index=False, encoding='utf-8-sig')  # UTF-8로 저장
    print(f"데이터가 {output_path}에 저장되었습니다.")

# %%
import os
import json
import pandas as pd

# 경로 리스트
paths = [
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_08.특허.저작권",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_05.행정",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_02.가사",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_10.개인정보.ICT",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_06.기업",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_07.근로자",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_09.금융조세",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_03.형사A(생활형)",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_04.형사B(일반형)",
    r"C:\Users\wjdtn\Downloads\115.법률-규정 텍스트 분석 데이터_고도화_상황에 따른 판례 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL_01.민사"
]

# 결과를 저장할 리스트
data = []

# 파일 탐색 및 데이터 추출
for path in paths:
    for file_name in os.listdir(path):
        if file_name.endswith('.json'):
            file_path = os.path.join(path, file_name)
            with open(file_path, 'r', encoding='utf-8') as file:
                content = json.load(file)
                # 필요한 데이터 추출
                extracted_data = {
                    # 사건 기본 정보
                    'id': content['info'].get('id'),
                    'dataType': content['info'].get('dataType'),
                    'caseNm': content['info'].get('caseNm'),
                    'caseTitle': content['info'].get('caseTitle'),
                    'courtType': content['info'].get('courtType'),
                    'courtNm': content['info'].get('courtNm'),
                    'judmnAdjuDe': content['info'].get('judmnAdjuDe'),
                    'caseNo': content['info'].get('caseNo'),
                    # 판결 요지
                    'jdgmn': content.get('jdgmn'),
                    # 판결 내용
                    'question_1': content['jdgmnInfo'][0].get('question') if content.get('jdgmnInfo') else None,
                    'answer_1': content['jdgmnInfo'][0].get('answer') if content.get('jdgmnInfo') else None,
                    # 판결 요약
                    'summ_contxt': content['Summary'][0].get('summ_contxt') if content.get('Summary') else None,
                    'summ_pass': content['Summary'][0].get('summ_pass') if content.get('Summary') else None,
                    # 키워드 태그
                    'keyword': content['keyword_tagg'][0].get('keyword') if content.get('keyword_tagg') else None,
                    # 참고 정보
                    'reference_rules': content['Reference_info'].get('reference_rules') if content.get('Reference_info') else None,
                    'reference_court_case': content['Reference_info'].get('reference_court_case') if content.get('Reference_info') else None,
                    # 분류 정보
                    'class_name': content['Class_info'].get('class_name') if content.get('Class_info') else None,
                    'instance_name': content['Class_info'].get('instance_name') if content.get('Class_info') else None
                }
                data.append(extracted_data)

# DataFrame으로 변환 및 저장
df = pd.DataFrame(data)
output_path = r"C:\Users\wjdtn\Downloads\law_data_extracted.csv"
df.to_csv(output_path, index=False, encoding="utf-8-sig")

print(f"데이터가 {output_path}에 저장되었습니다.")
